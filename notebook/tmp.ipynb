# %%
import cv2

# %%
model_path="../models/yolov8n.onnx", 
image_path="../data/coco8/images/val/000000000049.jpg"

# %%
img_path_str = str(image_path)
img = cv2.imread(img_path_str)
print(img.shape)
# Out:
# (500, 381, 3)
